# %%
# !nvidia-smi
# Out:
# Sat Apr 22 14:50:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P0    30W /  70W |    883MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # *clone Repository for the traffic *

# %%
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# Cloning into 'german-traffic-signs'...
# Unpacking objects: 100% (6/6), 117.80 MiB | 9.38 MiB/s, done.

# %%
# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
# !pip install keras-applications
# !pip install tensorflow
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from keras-applications) (3.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras-applications) (1.22.4)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.4.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (2.12.0)

# %% [markdown]
# # add all neccesary imports

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.utils import plot_model
from IPython.display import SVG
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras.utils.vis_utils import model_to_dot
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
import keras.backend as K
import tensorflow as tf
import random
import pickle
import pandas as pd
import cv2

# %%
np.random.seed(0)

# %% [markdown]
# # load the traffic data here

# %%
# TODO: Implement load the data here.
with open('german-traffic-signs/train.p', 'rb') as f:
    train_data = pickle.load(f)
with open('german-traffic-signs/valid.p', 'rb') as f:
    val_data = pickle.load(f)
with open('german-traffic-signs/test.p', 'rb') as f:
        test_data = pickle.load(f)

# %% [markdown]
# # spliting dataset into Train , Test And Validation

# %%
# Split out features and labels
X_train, y_train = train_data['features'], train_data['labels']
X_val, y_val = val_data['features'], val_data['labels']
X_test, y_test = test_data['features'], test_data['labels']
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %% [markdown]
# ## **Test** **the** **data** **set** **for** **completeness**

# %%
 assert(X_train.shape[0] == y_train.shape[0]), "The number of images is not equal to the number of labels."
 assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."
 assert(X_val.shape[0] == y_val.shape[0]), "The number of images is not equal to the number of labels."
 assert(X_val.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."
 assert(X_test.shape[0] == y_test.shape[0]), "The number of images is not equal to the number of labels."
 assert(X_test.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."

# %% [markdown]
# # **Read** **Traffic** **sign** **Names** **and** **class** **ID**

# %%
 data = pd.read_csv('german-traffic-signs/signnames.csv')
 print(data)
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %% [markdown]
# # **Visualizing** **Dataset**

# %%
num_of_samples=[]  
cols = 5
num_classes = 43  
fig, axs = plt.subplots(nrows=num_classes, ncols=cols, figsize=(5,50))
fig.tight_layout()
     
for i in range(cols):
    for j, row in data.iterrows():
      x_selected = X_train[y_train == j]
      axs[j][i].imshow(x_selected[random.randint(0,(len(x_selected) - 1)), :, :], cmap=plt.get_cmap('gray'))
      axs[j][i].axis("off")
      if i == 2:
        axs[j][i].set_title(str(j) + " - " + row["SignName"])
        num_of_samples.append(len(x_selected))

# %% [markdown]
# # **Visualizing** **Distibution** **of** **Dataset**

# %%
    print(num_of_samples)
    plt.figure(figsize=(12, 4))
    plt.bar(range(0, num_classes), num_of_samples)
    plt.title("Distribution of the train dataset")
    plt.xlabel("Class number")
    plt.ylabel("Number of images")
    plt.show()
# Out:
# [180, 1980, 2010, 1260, 1770, 1650, 360, 1290, 1260, 1320, 1800, 1170, 1890, 1920, 690, 540, 360, 990, 1080, 180, 300, 270, 330, 450, 240, 1350, 540, 210, 480, 240, 390, 690, 210, 599, 360, 1080, 330, 180, 1860, 270, 300, 210, 210]

# %% [markdown]
# # **preprocessing** **Operation**

# %%
def preprocess(img):
    #img =cv2.resize(img,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)
    img = img/255
    return img

# %% [markdown]
# # **Applying** **Preprocessing** **Operation** **to** **the** **training** ,**testing** **and** **Validation** **dataset**

# %%
X_train_rgb = np.array(list(map(preprocess, X_train)))
X_test_rgb = np.array(list(map(preprocess, X_test)))
X_val_rgb = np.array(list(map(preprocess, X_val)))
plt.imshow(X_train[random.randint(0, len(X_train) - 1)])
plt.axis('off')
print(X_train.shape)
# Out:
# (34799, 32, 32, 3)

# %% [markdown]
# # **gray** **scale** **conversion** **of** **images**

# %%
def grayscale(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img

# %% [markdown]
# # **histogram** **equalization**

# %%
def equalize(img):
    img = cv2.equalizeHist(img)
    return img

# %%
def preprocess_gray(img):
    img = grayscale(img)
    img = equalize(img)
    img = img/255
    return img

# %%
X_train_gray = np.array(list(map(preprocess_gray, X_train)))
X_test_gray = np.array(list(map(preprocess_gray, X_test)))
X_val_gray = np.array(list(map(preprocess_gray, X_val)))
 
plt.imshow(X_train_gray[random.randint(0, len(X_train_gray) - 1)])
plt.axis('off')
print(X_train_gray.shape)
# Out:
# (34799, 32, 32)

# %% [markdown]
# # **Reshaping** **data** **dimension**

# %%
X_train_gray = X_train_gray.reshape(34799, 32, 32, 1)
X_test_gray = X_test_gray.reshape(12630, 32, 32, 1)
X_val_gray = X_val_gray.reshape(4410, 32, 32, 1)

# %% [markdown]
# # **Gray** **Scale** **Augmentation**

# %%
 from keras.preprocessing.image import ImageDataGenerator
     
 datagen_gray = ImageDataGenerator(width_shift_range=0.1,
                                height_shift_range=0.1,
                                zoom_range=0.2,
                                shear_range=0.1,
                                rotation_range=10.)
     
 datagen_gray.fit(X_train_gray)

# %%
batches_gray = datagen_gray.flow(X_train_gray, y_train, batch_size = 5) 
X_batch_gray, y_batch_gray = next(batches_gray)
     
fig, axs = plt.subplots(1, 5, figsize=(12, 12))
fig.tight_layout()
     
for i in range(5):
  axs[i].imshow(X_batch_gray[i].reshape((32, 32)),cmap='gray')
  axs[i].axis("off")
     
print(X_batch_gray.shape)
# Out:
# (5, 32, 32, 1)

# %% [markdown]
# # **Augmentation** **for** **RGB** **images**

# %%
 from keras.preprocessing.image import ImageDataGenerator
     
 datagen_rgb = ImageDataGenerator(width_shift_range=0.1,
                                height_shift_range=0.1,
                                zoom_range=0.2,
                                shear_range=0.1,
                                rotation_range=10.)  
 datagen_rgb.fit(X_train_rgb)

# %%
batches_rgb = datagen_rgb.flow(X_train_rgb, y_train, batch_size = 5) 
X_batch_rgb, y_batch_rgb = next(batches_rgb)
     
fig, axs = plt.subplots(1, 5, figsize=(12, 12))
fig.tight_layout()
     
for i in range(5):
  axs[i].imshow(X_batch_rgb[i].reshape((32, 32,3)),cmap='gray')
  axs[i].axis("off")
     
print(X_batch_rgb.shape)
# Out:
# (5, 32, 32, 3)

# %% [markdown]
# # **one** **hot** **encoding** **of** **labels**

# %%
 y_train_cat = to_categorical(y_train, 43)
y_test_cat = to_categorical(y_test, 43)
y_val_cat = to_categorical(y_val, 43)

# %% [markdown]
# # VGG Model for the traffic signs

# %%
vgg=VGG16(input_shape=(32,32,3),weights='imagenet',include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable= True
x=Flatten()(vgg.output)
Last_layer=Dense(43,activation='softmax')(x)
vgg_model=Model(inputs=vgg.input,outputs=Last_layer)
vgg_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten_30 (Flatten)        (None, 512)               0
#
#  dense_70 (Dense)            (None, 43)                22059
#
# =================================================================
# Total params: 14,736,747
# Trainable params: 14,736,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg_model.compile(Adam(lr = 0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
vgg_history = vgg_model.fit_generator(datagen_rgb.flow(X_train_rgb, y_train_cat, batch_size=20),epochs=20,validation_data=(X_val_rgb, y_val_cat), shuffle = 1)
# Out:
# Epoch 1/20
# <ipython-input-89-7d97123d78bf>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   vgg_history = vgg_model.fit_generator(datagen_rgb.flow(X_train_rgb, y_train_cat, batch_size=20),epochs=20,validation_data=(X_val_rgb, y_val_cat), shuffle = 1)
# 1740/1740 [==============================] - 66s 30ms/step - loss: 2.2252 - accuracy: 0.3120 - val_loss: 1.2577 - val_accuracy: 0.5499
# Epoch 2/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.9280 - accuracy: 0.6727 - val_loss: 0.4690 - val_accuracy: 0.8385
# Epoch 3/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.3897 - accuracy: 0.8759 - val_loss: 0.3337 - val_accuracy: 0.8980
# Epoch 4/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.4574 - accuracy: 0.8873 - val_loss: 0.2607 - val_accuracy: 0.9256
# Epoch 5/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2286 - accuracy: 0.9403 - val_loss: 0.2886 - val_accuracy: 0.9252
# Epoch 6/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.1983 - accuracy: 0.9472 - val_loss: 0.4504 - val_accuracy: 0.8868
# Epoch 7/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2642 - accuracy: 0.9354 - val_loss: 0.1458 - val_accuracy: 0.9612
# Epoch 8/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2651 - accuracy: 0.9368 - val_loss: 0.2648 - val_accuracy: 0.9508
# Epoch 9/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2374 - accuracy: 0.9451 - val_loss: 0.1926 - val_accuracy: 0.9420
# Epoch 10/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2424 - accuracy: 0.9496 - val_loss: 0.2010 - val_accuracy: 0.9583
# Epoch 11/20
# 1740/1740 [==============================] - 46s 27ms/step - loss: 0.1882 - accuracy: 0.9593 - val_loss: 0.1540 - val_accuracy: 0.9689
# Epoch 12/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.1619 - accuracy: 0.9645 - val_loss: 0.1598 - val_accuracy: 0.9705
# Epoch 13/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.1607 - accuracy: 0.9672 - val_loss: 0.1771 - val_accuracy: 0.9717
# Epoch 14/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.1907 - accuracy: 0.9589 - val_loss: 0.1767 - val_accuracy: 0.9603
# Epoch 15/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2299 - accuracy: 0.9516 - val_loss: 0.2070 - val_accuracy: 0.9356
# Epoch 16/20
# 1740/1740 [==============================] - 46s 27ms/step - loss: 0.3107 - accuracy: 0.9310 - val_loss: 0.1881 - val_accuracy: 0.9637
# Epoch 17/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.1896 - accuracy: 0.9611 - val_loss: 0.6767 - val_accuracy: 0.9175
# Epoch 18/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2023 - accuracy: 0.9588 - val_loss: 0.1112 - val_accuracy: 0.9751
# Epoch 19/20
# 1740/1740 [==============================] - 48s 28ms/step - loss: 0.2108 - accuracy: 0.9596 - val_loss: 0.3328 - val_accuracy: 0.9649
# Epoch 20/20
# 1740/1740 [==============================] - 47s 27ms/step - loss: 0.2736 - accuracy: 0.9423 - val_loss: 0.1128 - val_accuracy: 0.9692

# %%
score = vgg_model.evaluate(X_test_rgb, y_test_cat, verbose=0)
print(score)
# Out:
# [0.2769000232219696, 0.9581947922706604]

# %% [markdown]
# # Resnet50  Implimentation for traffic sign classification

# %%
resnet=ResNet50(input_shape=(32,32,3),weights='imagenet',include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
for layer in resnet.layers:
  layer.trainable= True
x=Flatten()(resnet.output)
final_layer=Dense(43,activation='softmax')(x)
#prediction=Dense(1)(x)
resnet_model=Model(inputs=resnet.input,outputs=final_layer)
resnet_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_6[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 16, 16, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 8, 8, 256)    16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 8, 8, 256)    0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 8, 8, 64)     16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 8, 8, 256)    0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 8, 8, 64)     16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 8, 8, 256)    0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 4, 4, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 4, 4, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 4, 4, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 4, 4, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 4, 4, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 4, 4, 512)    0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 2, 2, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 2, 2, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 1, 1, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 1, 1, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 1, 1, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 1, 1, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten_31 (Flatten)           (None, 2048)         0           ['conv5_block3_out[0][0]']
#
#  dense_71 (Dense)               (None, 43)           88107       ['flatten_31[0][0]']
#
# ==================================================================================================
# Total params: 23,675,819
# Trainable params: 23,622,699
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
resnet_model.compile(Adam(lr = 0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
resnet_history = resnet_model.fit_generator(datagen_rgb.flow(X_train_rgb, y_train_cat, batch_size=20),epochs=20,validation_data=(X_val_rgb, y_val_cat), shuffle = 1)
# Out:
# Epoch 1/20
# <ipython-input-94-48dfd8d0d9fa>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   resnet_history = resnet_model.fit_generator(datagen_rgb.flow(X_train_rgb, y_train_cat, batch_size=20),epochs=20,validation_data=(X_val_rgb, y_val_cat), shuffle = 1)
# 1740/1740 [==============================] - 79s 41ms/step - loss: 3.0528 - accuracy: 0.2778 - val_loss: 15.2162 - val_accuracy: 0.0753
# Epoch 2/20
# 1740/1740 [==============================] - 75s 43ms/step - loss: 2.1153 - accuracy: 0.4286 - val_loss: 1.3516 - val_accuracy: 0.5327
# Epoch 3/20
# 1740/1740 [==============================] - 69s 40ms/step - loss: 1.0713 - accuracy: 0.6415 - val_loss: 0.7457 - val_accuracy: 0.7308
# Epoch 4/20
# 1740/1740 [==============================] - 69s 39ms/step - loss: 0.5922 - accuracy: 0.8088 - val_loss: 0.5330 - val_accuracy: 0.8252
# Epoch 5/20
# 1740/1740 [==============================] - 72s 42ms/step - loss: 0.3741 - accuracy: 0.8840 - val_loss: 0.7862 - val_accuracy: 0.8431
# Epoch 6/20
# 1740/1740 [==============================] - 69s 39ms/step - loss: 0.2853 - accuracy: 0.9145 - val_loss: 0.4419 - val_accuracy: 0.8683
# Epoch 7/20
# 1740/1740 [==============================] - 70s 40ms/step - loss: 0.2197 - accuracy: 0.9353 - val_loss: 0.4766 - val_accuracy: 0.8834
# Epoch 8/20
# 1740/1740 [==============================] - 73s 42ms/step - loss: 0.1756 - accuracy: 0.9463 - val_loss: 0.7086 - val_accuracy: 0.8537
# Epoch 9/20
# 1740/1740 [==============================] - 72s 41ms/step - loss: 0.1560 - accuracy: 0.9544 - val_loss: 0.3601 - val_accuracy: 0.9118
# Epoch 10/20
# 1740/1740 [==============================] - 71s 41ms/step - loss: 0.1481 - accuracy: 0.9568 - val_loss: 0.3364 - val_accuracy: 0.9143
# Epoch 11/20
# 1740/1740 [==============================] - 71s 41ms/step - loss: 0.1162 - accuracy: 0.9658 - val_loss: 0.3759 - val_accuracy: 0.9002
# Epoch 12/20
# 1740/1740 [==============================] - 67s 39ms/step - loss: 0.1139 - accuracy: 0.9686 - val_loss: 0.2077 - val_accuracy: 0.9444
# Epoch 13/20
# 1740/1740 [==============================] - 69s 40ms/step - loss: 0.1082 - accuracy: 0.9690 - val_loss: 0.3478 - val_accuracy: 0.9220
# Epoch 14/20
# 1740/1740 [==============================] - 68s 39ms/step - loss: 0.0892 - accuracy: 0.9748 - val_loss: 2.1251 - val_accuracy: 0.8930
# Epoch 15/20
# 1740/1740 [==============================] - 69s 39ms/step - loss: 0.0881 - accuracy: 0.9749 - val_loss: 0.3628 - val_accuracy: 0.9254
# Epoch 16/20
# 1740/1740 [==============================] - 67s 39ms/step - loss: 0.0894 - accuracy: 0.9753 - val_loss: 0.4680 - val_accuracy: 0.9091
# Epoch 17/20
# 1740/1740 [==============================] - 68s 39ms/step - loss: 0.0827 - accuracy: 0.9761 - val_loss: 1.8553 - val_accuracy: 0.9186
# Epoch 18/20
# 1740/1740 [==============================] - 68s 39ms/step - loss: 0.0796 - accuracy: 0.9788 - val_loss: 0.5652 - val_accuracy: 0.8948
# Epoch 19/20
# 1740/1740 [==============================] - 68s 39ms/step - loss: 0.0785 - accuracy: 0.9793 - val_loss: 0.2433 - val_accuracy: 0.9465
# Epoch 20/20
# 1740/1740 [==============================] - 69s 39ms/step - loss: 0.0568 - accuracy: 0.9844 - val_loss: 0.2235 - val_accuracy: 0.9531

# %%
score = resnet_model.evaluate(X_test_rgb, y_test_cat, verbose=0)
print(score)
# Out:
# [0.30759865045547485, 0.9439429640769958]

# %% [markdown]
# # **Inception** **Model**

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.layers import Dense, Flatten
from keras.models import Model

inception = InceptionV3(input_shape=(75, 75, 3), weights='imagenet', include_top=False)
for layer in inception.layers:
    layer.trainable = True
x = Flatten()(inception.output)
final_layer = Dense(43, activation='softmax')(x)
inception_model=Model(inputs=inception.input,outputs=final_layer)
inception_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  conv2d_392 (Conv2D)            (None, 37, 37, 32)   864         ['input_7[0][0]']
#
#  batch_normalization_282 (Batch  (None, 37, 37, 32)  96          ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_282[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_282[0][0]']
#
#  batch_normalization_283 (Batch  (None, 35, 35, 32)  96          ['conv2d_393[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_283[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 35, 35, 64)   18432       ['activation_283[0][0]']
#
#  batch_normalization_284 (Batch  (None, 35, 35, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_284[0][0]']
#
#  max_pooling2d_64 (MaxPooling2D  (None, 17, 17, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_395 (Conv2D)            (None, 17, 17, 80)   5120        ['max_pooling2d_64[0][0]']
#
#  batch_normalization_285 (Batch  (None, 17, 17, 80)  240         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 17, 17, 80)   0           ['batch_normalization_285[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 15, 15, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 15, 15, 192)  576        ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 15, 15, 192)  0           ['batch_normalization_286[0][0]']
#
#  max_pooling2d_65 (MaxPooling2D  (None, 7, 7, 192)   0           ['activation_286[0][0]']
#  )
#
#  conv2d_400 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_65[0][0]']
#
#  batch_normalization_290 (Batch  (None, 7, 7, 64)    192         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_290[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_65[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_290[0][0]']
#
#  batch_normalization_288 (Batch  (None, 7, 7, 48)    144         ['conv2d_398[0][0]']
#  Normalization)
#
#  batch_normalization_291 (Batch  (None, 7, 7, 96)    288         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_288[0][0]']
#
#  activation_291 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_291[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 7, 7, 192)   0           ['max_pooling2d_65[0][0]']
#  ooling2D)
#
#  conv2d_397 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_65[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_288[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_291[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 7, 7, 32)     6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (Batch  (None, 7, 7, 64)    192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_289 (Batch  (None, 7, 7, 64)    192         ['conv2d_399[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 7, 7, 96)    288         ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 7, 7, 32)    96          ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_287[0][0]']
#
#  activation_289 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_289[0][0]']
#
#  activation_292 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_292[0][0]']
#
#  activation_293 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_293[0][0]']
#
#  mixed0 (Concatenate)           (None, 7, 7, 256)    0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  batch_normalization_297 (Batch  (None, 7, 7, 64)    192         ['conv2d_407[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_297[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 7, 7, 48)     12288       ['mixed0[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_297[0][0]']
#
#  batch_normalization_295 (Batch  (None, 7, 7, 48)    144         ['conv2d_405[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 7, 7, 96)    288         ['conv2d_408[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_295[0][0]']
#
#  activation_298 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_298[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 7, 7, 256)   0           ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_404 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_295[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_298[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 7, 7, 64)     16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_294 (Batch  (None, 7, 7, 64)    192         ['conv2d_404[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 7, 7, 64)    192         ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 7, 7, 96)    288         ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 7, 7, 64)    192         ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_294[0][0]']
#
#  activation_296 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_296[0][0]']
#
#  activation_299 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_299[0][0]']
#
#  activation_300 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_300[0][0]']
#
#  mixed1 (Concatenate)           (None, 7, 7, 288)    0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  batch_normalization_304 (Batch  (None, 7, 7, 64)    192         ['conv2d_414[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_304[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 7, 7, 48)     13824       ['mixed1[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_304[0][0]']
#
#  batch_normalization_302 (Batch  (None, 7, 7, 48)    144         ['conv2d_412[0][0]']
#  Normalization)
#
#  batch_normalization_305 (Batch  (None, 7, 7, 96)    288         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_302[0][0]']
#
#  activation_305 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_305[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 7, 7, 288)   0           ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_411 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_302[0][0]']
#
#  conv2d_416 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_305[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 7, 7, 64)     18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_301 (Batch  (None, 7, 7, 64)    192         ['conv2d_411[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 7, 7, 64)    192         ['conv2d_413[0][0]']
#  Normalization)
#
#  batch_normalization_306 (Batch  (None, 7, 7, 96)    288         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 7, 7, 64)    192         ['conv2d_417[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_301[0][0]']
#
#  activation_303 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_303[0][0]']
#
#  activation_306 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_306[0][0]']
#
#  activation_307 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_307[0][0]']
#
#  mixed2 (Concatenate)           (None, 7, 7, 288)    0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed2[0][0]']
#
#  batch_normalization_309 (Batch  (None, 7, 7, 64)    192         ['conv2d_419[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_309[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_309[0][0]']
#
#  batch_normalization_310 (Batch  (None, 7, 7, 96)    288         ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_310[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 3, 3, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 3, 3, 96)     82944       ['activation_310[0][0]']
#
#  batch_normalization_308 (Batch  (None, 3, 3, 384)   1152        ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 3, 3, 96)    288         ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_308[0][0]']
#
#  activation_311 (Activation)    (None, 3, 3, 96)     0           ['batch_normalization_311[0][0]']
#
#  max_pooling2d_66 (MaxPooling2D  (None, 3, 3, 288)   0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 3, 3, 768)    0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_66[0][0]']
#
#  conv2d_426 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_316 (Batch  (None, 3, 3, 128)   384         ['conv2d_426[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_316[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_316[0][0]']
#
#  batch_normalization_317 (Batch  (None, 3, 3, 128)   384         ['conv2d_427[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_317[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_317[0][0]']
#
#  batch_normalization_313 (Batch  (None, 3, 3, 128)   384         ['conv2d_423[0][0]']
#  Normalization)
#
#  batch_normalization_318 (Batch  (None, 3, 3, 128)   384         ['conv2d_428[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_313[0][0]']
#
#  activation_318 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_318[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_313[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_318[0][0]']
#
#  batch_normalization_314 (Batch  (None, 3, 3, 128)   384         ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 3, 3, 128)   384         ['conv2d_429[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_314[0][0]']
#
#  activation_319 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_319[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 3, 3, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_422 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_314[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_319[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_312 (Batch  (None, 3, 3, 192)   576         ['conv2d_422[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 3, 3, 192)   576         ['conv2d_425[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 3, 3, 192)   576         ['conv2d_430[0][0]']
#  Normalization)
#
#  batch_normalization_321 (Batch  (None, 3, 3, 192)   576         ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_312[0][0]']
#
#  activation_315 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_315[0][0]']
#
#  activation_320 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_320[0][0]']
#
#  activation_321 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_321[0][0]']
#
#  mixed4 (Concatenate)           (None, 3, 3, 768)    0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_436 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_326 (Batch  (None, 3, 3, 160)   480         ['conv2d_436[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_326[0][0]']
#
#  conv2d_437 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_326[0][0]']
#
#  batch_normalization_327 (Batch  (None, 3, 3, 160)   480         ['conv2d_437[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_327[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_438 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_327[0][0]']
#
#  batch_normalization_323 (Batch  (None, 3, 3, 160)   480         ['conv2d_433[0][0]']
#  Normalization)
#
#  batch_normalization_328 (Batch  (None, 3, 3, 160)   480         ['conv2d_438[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_323[0][0]']
#
#  activation_328 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_328[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_323[0][0]']
#
#  conv2d_439 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_328[0][0]']
#
#  batch_normalization_324 (Batch  (None, 3, 3, 160)   480         ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 3, 3, 160)   480         ['conv2d_439[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_324[0][0]']
#
#  activation_329 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_329[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 3, 3, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_432 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_324[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_329[0][0]']
#
#  conv2d_441 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_322 (Batch  (None, 3, 3, 192)   576         ['conv2d_432[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 3, 3, 192)   576         ['conv2d_435[0][0]']
#  Normalization)
#
#  batch_normalization_330 (Batch  (None, 3, 3, 192)   576         ['conv2d_440[0][0]']
#  Normalization)
#
#  batch_normalization_331 (Batch  (None, 3, 3, 192)   576         ['conv2d_441[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_322[0][0]']
#
#  activation_325 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_325[0][0]']
#
#  activation_330 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_330[0][0]']
#
#  activation_331 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_331[0][0]']
#
#  mixed5 (Concatenate)           (None, 3, 3, 768)    0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#
#  conv2d_446 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_336 (Batch  (None, 3, 3, 160)   480         ['conv2d_446[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_336[0][0]']
#
#  conv2d_447 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_336[0][0]']
#
#  batch_normalization_337 (Batch  (None, 3, 3, 160)   480         ['conv2d_447[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_337[0][0]']
#
#  conv2d_443 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_448 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_337[0][0]']
#
#  batch_normalization_333 (Batch  (None, 3, 3, 160)   480         ['conv2d_443[0][0]']
#  Normalization)
#
#  batch_normalization_338 (Batch  (None, 3, 3, 160)   480         ['conv2d_448[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_333[0][0]']
#
#  activation_338 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_338[0][0]']
#
#  conv2d_444 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_333[0][0]']
#
#  conv2d_449 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_338[0][0]']
#
#  batch_normalization_334 (Batch  (None, 3, 3, 160)   480         ['conv2d_444[0][0]']
#  Normalization)
#
#  batch_normalization_339 (Batch  (None, 3, 3, 160)   480         ['conv2d_449[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_334[0][0]']
#
#  activation_339 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_339[0][0]']
#
#  average_pooling2d_32 (AverageP  (None, 3, 3, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_442 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_445 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_334[0][0]']
#
#  conv2d_450 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_339[0][0]']
#
#  conv2d_451 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_32[0][0]']
#
#  batch_normalization_332 (Batch  (None, 3, 3, 192)   576         ['conv2d_442[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 3, 3, 192)   576         ['conv2d_445[0][0]']
#  Normalization)
#
#  batch_normalization_340 (Batch  (None, 3, 3, 192)   576         ['conv2d_450[0][0]']
#  Normalization)
#
#  batch_normalization_341 (Batch  (None, 3, 3, 192)   576         ['conv2d_451[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_332[0][0]']
#
#  activation_335 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_335[0][0]']
#
#  activation_340 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_340[0][0]']
#
#  activation_341 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_341[0][0]']
#
#  mixed6 (Concatenate)           (None, 3, 3, 768)    0           ['activation_332[0][0]',
#                                                                   'activation_335[0][0]',
#                                                                   'activation_340[0][0]',
# ...
#  conv2d_472 (Conv2D)            (None, 1, 1, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_362 (Batch  (None, 1, 1, 448)   1344        ['conv2d_472[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_362[0][0]']
#
#  conv2d_469 (Conv2D)            (None, 1, 1, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_473 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_362[0][0]']
#
#  batch_normalization_359 (Batch  (None, 1, 1, 384)   1152        ['conv2d_469[0][0]']
#  Normalization)
#
#  batch_normalization_363 (Batch  (None, 1, 1, 384)   1152        ['conv2d_473[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_359[0][0]']
#
#  activation_363 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_363[0][0]']
#
#  conv2d_470 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_471 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_363[0][0]']
#
#  conv2d_475 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_363[0][0]']
#
#  average_pooling2d_34 (AverageP  (None, 1, 1, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_468 (Conv2D)            (None, 1, 1, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_360 (Batch  (None, 1, 1, 384)   1152        ['conv2d_470[0][0]']
#  Normalization)
#
#  batch_normalization_361 (Batch  (None, 1, 1, 384)   1152        ['conv2d_471[0][0]']
#  Normalization)
#
#  batch_normalization_364 (Batch  (None, 1, 1, 384)   1152        ['conv2d_474[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 1, 1, 384)   1152        ['conv2d_475[0][0]']
#  Normalization)
#
#  conv2d_476 (Conv2D)            (None, 1, 1, 192)    245760      ['average_pooling2d_34[0][0]']
#
#  batch_normalization_358 (Batch  (None, 1, 1, 320)   960         ['conv2d_468[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_360[0][0]']
#
#  activation_361 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_361[0][0]']
#
#  activation_364 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_364[0][0]']
#
#  activation_365 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_365[0][0]']
#
#  batch_normalization_366 (Batch  (None, 1, 1, 192)   576         ['conv2d_476[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_358[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 1, 1, 768)    0           ['activation_360[0][0]',
#                                                                   'activation_361[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 1, 1, 768)    0           ['activation_364[0][0]',
#                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_366[0][0]']
#
#  mixed9 (Concatenate)           (None, 1, 1, 2048)   0           ['activation_358[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv2d_481 (Conv2D)            (None, 1, 1, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_371 (Batch  (None, 1, 1, 448)   1344        ['conv2d_481[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_371[0][0]']
#
#  conv2d_478 (Conv2D)            (None, 1, 1, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_482 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_371[0][0]']
#
#  batch_normalization_368 (Batch  (None, 1, 1, 384)   1152        ['conv2d_478[0][0]']
#  Normalization)
#
#  batch_normalization_372 (Batch  (None, 1, 1, 384)   1152        ['conv2d_482[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_368[0][0]']
#
#  activation_372 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_372[0][0]']
#
#  conv2d_479 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_372[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_372[0][0]']
#
#  average_pooling2d_35 (AverageP  (None, 1, 1, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_477 (Conv2D)            (None, 1, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_369 (Batch  (None, 1, 1, 384)   1152        ['conv2d_479[0][0]']
#  Normalization)
#
#  batch_normalization_370 (Batch  (None, 1, 1, 384)   1152        ['conv2d_480[0][0]']
#  Normalization)
#
#  batch_normalization_373 (Batch  (None, 1, 1, 384)   1152        ['conv2d_483[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 1, 1, 384)   1152        ['conv2d_484[0][0]']
#  Normalization)
#
#  conv2d_485 (Conv2D)            (None, 1, 1, 192)    393216      ['average_pooling2d_35[0][0]']
#
#  batch_normalization_367 (Batch  (None, 1, 1, 320)   960         ['conv2d_477[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_369[0][0]']
#
#  activation_370 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_370[0][0]']
#
#  activation_373 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_373[0][0]']
#
#  activation_374 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_374[0][0]']
#
#  batch_normalization_375 (Batch  (None, 1, 1, 192)   576         ['conv2d_485[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_367[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 1, 768)    0           ['activation_369[0][0]',
#                                                                   'activation_370[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 1, 1, 768)    0           ['activation_373[0][0]',
#                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_375[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 1, 2048)   0           ['activation_367[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'activation_375[0][0]']
#
#  flatten_32 (Flatten)           (None, 2048)         0           ['mixed10[0][0]']
#
#  dense_72 (Dense)               (None, 43)           88107       ['flatten_32[0][0]']
#
# ==================================================================================================
# Total params: 21,890,891
# Trainable params: 21,856,459
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
#resnet=ResNet50
#inception_model.summary()

# %% [markdown]
# MOBILENET

# %%
from keras.applications.mobilenet import MobileNet

mobilenet = MobileNet(input_shape=(32, 32, 3), weights='imagenet', include_top=False)
for layer in mobilenet.layers:
    layer.trainable = True
x = Flatten()(mobilenet.output)
final_layer = Dense(43, activation='softmax')(x)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# # Modified AlexNet

# %%
# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

def modified_alexnet():
  model = Sequential()
  model.add(Conv2D(32, (5, 5), input_shape=(32, 32, 1), activation='relu'))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(Conv2D(30, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(30, (3, 3), activation='relu'))
  
  model.add(Flatten())
  model.add(Dense(600, activation='relu'))
  #model.add(BatchNormalization())
  model.add(Dense(400, activation='relu'))
  #model.add(Dropout(0.5))
  
  model.add(Dense(43, activation='softmax'))
  
  model.compile(Adam(lr = 0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
def modified_alexnet():
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape=(32, 32, 1), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(43, activation='softmax'))
    return model

modified_alex = modified_alexnet()
print(modified_alex.summary())
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_486 (Conv2D)         (None, 28, 28, 32)        832
#
#  conv2d_487 (Conv2D)         (None, 26, 26, 64)        18496
#
#  max_pooling2d_68 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_488 (Conv2D)         (None, 11, 11, 128)       73856
#
#  max_pooling2d_69 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_34 (Flatten)        (None, 3200)              0
#
#  dense_74 (Dense)            (None, 512)               1638912
#
#  dense_75 (Dense)            (None, 43)                22059
#
# =================================================================
# Total params: 1,754,155
# Trainable params: 1,754,155
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# from keras.preprocessing.image import ImageDataGenerator

# # Create an ImageDataGenerator instance for data augmentation
# datagen_gray = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip=False,
#     fill_mode='nearest'
# )

# # Fit the generator to the training data
# datagen_gray.fit(X_train_gray)

# %%
m_alex_history = modified_alex.fit_generator(datagen_gray.flow(X_train_gray, y_train_cat, batch_size=40),epochs=20,validation_data=(X_val_gray, y_val_cat), shuffle = 1)
# Out:
# <ipython-input-102-de40d11d20b3>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m_alex_history = modified_alex.fit_generator(datagen_gray.flow(X_train_gray, y_train_cat, batch_size=40),epochs=20,validation_data=(X_val_gray, y_val_cat), shuffle = 1)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-102-de40d11d20b3> in <cell line: 1>()
# ----> 1 m_alex_history = modified_alex.fit_generator(datagen_gray.flow(X_train_gray, y_train_cat, batch_size=40),epochs=20,validation_data=(X_val_gray, y_val_cat), shuffle = 1)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2634             stacklevel=2,
#    2635         )
# -> 2636         return self.fit(
#    2637             generator,
#    2638             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in _assert_compile_was_called(self)
#    3683         # (i.e. whether the model is built and its inputs/outputs are set).
#    3684         if not self._is_compiled:
# -> 3685             raise RuntimeError(
#    3686                 "You must compile your model before "
#    3687                 "training/testing. "
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
score = modified_alex.evaluate(X_test_gray, y_test_cat, verbose=0)
print(score)

# %% [markdown]
# # **plots** **section**

# %%
plt.plot(vgg_history.history['val_accuracy'])
plt.plot(resnet_history.history['val_accuracy'])
plt.plot(m_alex_history.history['val_accuracy'])
plt.legend(['Modified_AlexNet','Resnet50','VGG'])
plt.title('Val_accuracy',fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
plt.xlabel('epoch',fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-c5c04beac15c> in <cell line: 3>()
#       1 plt.plot(vgg_history.history['val_accuracy'])
#       2 plt.plot(resnet_history.history['val_accuracy'])
# ----> 3 plt.plot(m_alex_history.history['val_accuracy'])
#       4 plt.legend(['Modified_AlexNet','Resnet50','VGG'])
#       5 plt.title('Val_accuracy',fontsize=15)
#
# NameError: name 'm_alex_history' is not defined

# %%
# Resnet plots
plt.plot(resnet_history.history['accuracy'])
plt.plot(resnet_history.history['val_accuracy'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('Resnet-50 Accuracy',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(resnet_history.history['loss'])
plt.plot(resnet_history.history['val_loss'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('Resnet-50 Loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Loss',fontsize=15)
# Out:
# Text(0, 0.5, 'Loss')

# %%
# VGG plots
plt.plot(vgg_history.history['accuracy'])
plt.plot(vgg_history.history['val_accuracy'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('VGG-16 Accuracy',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(vgg_history.history['loss'])
plt.plot(vgg_history.history['val_loss'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('VGG-16 Loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Loss',fontsize=15)
# Out:
# Text(0, 0.5, 'Loss')

# %%
#Modified Alexnet
plt.plot(m_alex_history.history['accuracy'])
plt.plot(m_alex_history.history['val_accuracy'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('Modified AlexNet Accuracy',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-06dbb0c9176a> in <cell line: 2>()
#       1 #Modified Alexnet
# ----> 2 plt.plot(m_alex_history.history['accuracy'])
#       3 plt.plot(m_alex_history.history['val_accuracy'])
#       4 plt.legend(['training','Validation'],fontsize=15)
#       5 plt.title('Modified AlexNet Accuracy',fontsize=15)
#
# NameError: name 'm_alex_history' is not defined

# %%
plt.plot(m_alex_history.history['loss'])
plt.plot(m_alex_history.history['val_loss'])
plt.legend(['training','Validation'],fontsize=15)
plt.title('Modified Alex Loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.ylabel('Loss',fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-0e43ad430d7f> in <cell line: 1>()
# ----> 1 plt.plot(m_alex_history.history['loss'])
#       2 plt.plot(m_alex_history.history['val_loss'])
#       3 plt.legend(['training','Validation'],fontsize=15)
#       4 plt.title('Modified Alex Loss',fontsize=15)
#       5 plt.xlabel('epoch',fontsize=15)
#
# NameError: name 'm_alex_history' is not defined
